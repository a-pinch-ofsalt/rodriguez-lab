# %%
# !pip install antiberty
# !pip install pandas torch
# Out:
# Looking in links: /path/to/your/local/wheel/directory
# Requirement already satisfied: antiberty in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (0.1.3)
# Requirement already satisfied: torch>=1.7.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from antiberty) (2.6.0+cu126)
# Requirement already satisfied: transformers>=4.5.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from antiberty) (4.52.4)
# Requirement already satisfied: filelock in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (4.12.2)
# Requirement already satisfied: setuptools in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (1.13.1)
# Requirement already satisfied: networkx in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (3.4.2)
# Requirement already satisfied: jinja2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (3.1.6)
# Requirement already satisfied: fsspec in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (12.6.85)
# Requirement already satisfied: triton==3.2.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch>=1.7.1->antiberty) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.7.1->antiberty) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (2024.11.6)
# Requirement already satisfied: requests in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from transformers>=4.5.1->antiberty) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.5.1->antiberty) (1.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from jinja2->torch>=1.7.1->antiberty) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from requests->transformers>=4.5.1->antiberty) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from requests->transformers>=4.5.1->antiberty) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from requests->transformers>=4.5.1->antiberty) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from requests->transformers>=4.5.1->antiberty) (2025.4.26)
# Looking in links: /path/to/your/local/wheel/directory
# Requirement already satisfied: pandas in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: torch in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (2.6.0+cu126)
# Requirement already satisfied: numpy>=1.26.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (12.6.85)
# Requirement already satisfied: triton==3.2.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fhici/miniconda3/envs/notebook/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)

# %%
import os
import pandas as pd
import torch
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
from antiberty import AntiBERTyRunner
from tqdm.notebook import tqdm  # Classic terminal/CLI progress bar
import pickle
import numpy as np
input_dir = "../cdr3_outputs/h/"
output_dir = "../cdr3_outputs/embedded/"

os.makedirs(output_dir, exist_ok=True)

# %%
runner = AntiBERTyRunner()
runner.model.eval()
if torch.cuda.is_available():
    runner.model.cuda()


def embed_unique_cdr3s(cdr3_list):
    seen = {}
    #gpu mem usage ~batch_size^2 KB
    batch_size = 1500
    total_batches = (len(cdr3_list) + batch_size - 1) // batch_size

    with tqdm(total=total_batches, desc="🧬 Embedding unique CDR3s") as pbar:
        for i in range(0, len(cdr3_list), batch_size):
            batch = cdr3_list[i:i+batch_size]
            to_embed = [cdr3 for cdr3 in batch if cdr3 not in seen]
            if not to_embed:
                pbar.update(1)
                continue
            
            with torch.no_grad():
                reps = runner.embed(to_embed)
            for cdr3, rep in zip(to_embed, reps):
                pooled = rep[1:-1].mean(dim=0).cpu().numpy()
                seen[cdr3] = pooled
            pbar.update(1)
    return seen

# %%
# Loop 1: embed and save embeddings as .pkl
tsv_files = [f for f in os.listdir(input_dir) if f.endswith(".csv")] 
for filename in tqdm(tsv_files, total=len(tsv_files), desc="📄 Embedding + Pickle Save"):
    file_path = os.path.join(input_dir, filename)
    try:
        df = pd.read_csv(file_path)
    except Exception as e:
        print(f"Failed to read {filename}: {e}")
        continue

    if 'cdr3_aa' not in df.columns or 'stage' not in df.columns:
        print(f"[!] Skipping {filename} - missing required columns.")
        continue

    unique_cdr3s_in_file = list(set(df['cdr3_aa'].dropna()))
    embeddings = embed_unique_cdr3s(unique_cdr3s_in_file)

    # Save the embeddings as a pickle file
    pkl_name = filename.replace(".csv", "_embeddings.pkl")
    pkl_path = os.path.join(output_dir, pkl_name)
    with open(pkl_path, "wb") as f:
        pickle.dump(embeddings, f)

    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    import gc
# Out:
# 📄 Embedding + Pickle Save:   0%|          | 0/1 [00:00<?, ?it/s]
# 🧬 Embedding unique CDR3s:   0%|          | 0/99 [00:00<?, ?it/s]

# %%
# Loop 2: load pickles and write full CSVs
tsv_files = [f for f in os.listdir(input_dir) if f.endswith(".csv")] 
for filename in tqdm(tsv_files, total=len(tsv_files), desc="📄 Writing CSVs"):
    file_path = os.path.join(input_dir, filename)
    try:
        print("1")
        df = pd.read_csv(file_path)
    except Exception as e:
        print(f"Failed to read {filename}: {e}")
        continue
        
    if 'cdr3_aa' not in df.columns or 'stage' not in df.columns:
        print(f"[!] Skipping {filename} - missing required columns.")
        continue
    print("1")
    pkl_name = filename.replace(".csv", "_embeddings.pkl")
    pkl_path = os.path.join(output_dir, pkl_name)
    if not os.path.exists(pkl_path):
        print(f"[!] Missing pickle for {filename}, skipping")
        continue
    print("1")
    with open(pkl_path, "rb") as f:
        embeddings = pickle.load(f)
    print("1")
    emb_rows = []
    for idx, cdr3 in enumerate(set(df['cdr3_aa'].dropna())):
        if cdr3 not in embeddings:
            continue
        emb = embeddings[cdr3]

        if not isinstance(emb, np.ndarray):
            print(f"[!] {cdr3} embedding is not ndarray, skipping")
            continue
        if emb.shape != (512,):
            print(f"[!] {cdr3} has wrong shape: {emb.shape}, skipping")
            continue

        emb_rows.append([cdr3] + emb.tolist())

        if idx % 100 == 0:
            print(f"  processed {idx} CDR3s")

    print("1")
    output_path = os.path.join(output_dir, filename.replace(".csv", "_with_antiberty.csv"))
    chunk_size = 10000
    for i in range(0, len(emb_rows), chunk_size):
        chunk = emb_rows[i:i + chunk_size]
        emb_df_chunk = pd.DataFrame(chunk, columns=['cdr3_aa'] + [f'dim{i}' for i in range(512)])
        merged_chunk = pd.merge(df[['cdr3_aa', 'stage']], emb_df_chunk, on='cdr3_aa', how='inner')

        mode = 'w' if i == 0 else 'a'
        header = (i == 0)
        merged_chunk.to_csv(output_path, mode=mode, header=header, index=False)
        print(f"✅ Wrote rows {i} to {i+chunk_size}")


    print("1")
# Out:
# 📄 Writing CSVs:   0%|          | 0/1 [00:00<?, ?it/s]
# 1
# 1
# 1
# 1
#   processed 0 CDR3s
#   processed 100 CDR3s
#   processed 200 CDR3s
#   processed 300 CDR3s
#   processed 400 CDR3s
#   processed 500 CDR3s
#   processed 600 CDR3s
#   processed 700 CDR3s
#   processed 800 CDR3s
#   processed 900 CDR3s
#   processed 1000 CDR3s
#   processed 1100 CDR3s
#   processed 1200 CDR3s
#   processed 1300 CDR3s
#   processed 1400 CDR3s
#   processed 1500 CDR3s
#   processed 1600 CDR3s
#   processed 1700 CDR3s
#   processed 1800 CDR3s
#   processed 1900 CDR3s
#   processed 2000 CDR3s
#   processed 2100 CDR3s
#   processed 2200 CDR3s
#   processed 2300 CDR3s
#   processed 2400 CDR3s
#   processed 2500 CDR3s
#   processed 2600 CDR3s
#   processed 2700 CDR3s
#   processed 2800 CDR3s
#   processed 2900 CDR3s
#   processed 3000 CDR3s
#   processed 3100 CDR3s
#   processed 3200 CDR3s
#   processed 3300 CDR3s
#   processed 3400 CDR3s
#   processed 3500 CDR3s
#   processed 3600 CDR3s
#   processed 3700 CDR3s
#   processed 3800 CDR3s
#   processed 3900 CDR3s
#   processed 4000 CDR3s
#   processed 4100 CDR3s
#   processed 4200 CDR3s
#   processed 4300 CDR3s
#   processed 4400 CDR3s
#   processed 4500 CDR3s
#   processed 4600 CDR3s
#   processed 4700 CDR3s
#   processed 4800 CDR3s
#   processed 4900 CDR3s
#   processed 5000 CDR3s
#   processed 5100 CDR3s
#   processed 5200 CDR3s
#   processed 5300 CDR3s
#   processed 5400 CDR3s
#   processed 5500 CDR3s
#   processed 5600 CDR3s
#   processed 5700 CDR3s
#   processed 5800 CDR3s
#   processed 5900 CDR3s
#   processed 6000 CDR3s
#   processed 6100 CDR3s
#   processed 6200 CDR3s
#   processed 6300 CDR3s
#   processed 6400 CDR3s
#   processed 6500 CDR3s
#   processed 6600 CDR3s
#   processed 6700 CDR3s
#   processed 6800 CDR3s
#   processed 6900 CDR3s
#   processed 7000 CDR3s
#   processed 7100 CDR3s
#   processed 7200 CDR3s
#   processed 7300 CDR3s
#   processed 7400 CDR3s
#   processed 7500 CDR3s
#   processed 7600 CDR3s
#   processed 7700 CDR3s
#   processed 7800 CDR3s
#   processed 7900 CDR3s
#   processed 8000 CDR3s
#   processed 8100 CDR3s
#   processed 8200 CDR3s
#   processed 8300 CDR3s
#   processed 8400 CDR3s
#   processed 8500 CDR3s
#   processed 8600 CDR3s
#   processed 8700 CDR3s
#   processed 8800 CDR3s
#   processed 8900 CDR3s
#   processed 9000 CDR3s
#   processed 9100 CDR3s
#   processed 9200 CDR3s
#   processed 9300 CDR3s
#   processed 9400 CDR3s
#   processed 9500 CDR3s
#   processed 9600 CDR3s
#   processed 9700 CDR3s
#   processed 9800 CDR3s
#   processed 9900 CDR3s
#   processed 10000 CDR3s
#   processed 10100 CDR3s
#   processed 10200 CDR3s
#   processed 10300 CDR3s
#   processed 10400 CDR3s
#   processed 10500 CDR3s
#   processed 10600 CDR3s
#   processed 10700 CDR3s
#   processed 10800 CDR3s
#   processed 10900 CDR3s
#   processed 11000 CDR3s
#   processed 11100 CDR3s
#   processed 11200 CDR3s
#   processed 11300 CDR3s
#   processed 11400 CDR3s
#   processed 11500 CDR3s
#   processed 11600 CDR3s
#   processed 11700 CDR3s
#   processed 11800 CDR3s
#   processed 11900 CDR3s
#   processed 12000 CDR3s
#   processed 12100 CDR3s
#   processed 12200 CDR3s
#   processed 12300 CDR3s
#   processed 12400 CDR3s
#   processed 12500 CDR3s
#   processed 12600 CDR3s
#   processed 12700 CDR3s
#   processed 12800 CDR3s
#   processed 12900 CDR3s
#   processed 13000 CDR3s
#   processed 13100 CDR3s
#   processed 13200 CDR3s
#   processed 13300 CDR3s
#   processed 13400 CDR3s
#   processed 13500 CDR3s
#   processed 13600 CDR3s
#   processed 13700 CDR3s
#   processed 13800 CDR3s
#   processed 13900 CDR3s
#   processed 14000 CDR3s
#   processed 14100 CDR3s
#   processed 14200 CDR3s
#   processed 14300 CDR3s
#   processed 14400 CDR3s
#   processed 14500 CDR3s
#   processed 14600 CDR3s
#   processed 14700 CDR3s
#   processed 14800 CDR3s
#   processed 14900 CDR3s
#   processed 15000 CDR3s
#   processed 15100 CDR3s
#   processed 15200 CDR3s
#   processed 15300 CDR3s
#   processed 15400 CDR3s
#   processed 15500 CDR3s
#   processed 15600 CDR3s
#   processed 15700 CDR3s
#   processed 15800 CDR3s
#   processed 15900 CDR3s
#   processed 16000 CDR3s
#   processed 16100 CDR3s
#   processed 16200 CDR3s
#   processed 16300 CDR3s
#   processed 16400 CDR3s
#   processed 16500 CDR3s
#   processed 16600 CDR3s
#   processed 16700 CDR3s
#   processed 16800 CDR3s
#   processed 16900 CDR3s
#   processed 17000 CDR3s
#   processed 17100 CDR3s
#   processed 17200 CDR3s
#   processed 17300 CDR3s
#   processed 17400 CDR3s
#   processed 17500 CDR3s
#   processed 17600 CDR3s
#   processed 17700 CDR3s
#   processed 17800 CDR3s
#   processed 17900 CDR3s
#   processed 18000 CDR3s
#   processed 18100 CDR3s
#   processed 18200 CDR3s
#   processed 18300 CDR3s
#   processed 18400 CDR3s
#   processed 18500 CDR3s
#   processed 18600 CDR3s
#   processed 18700 CDR3s
#   processed 18800 CDR3s
#   processed 18900 CDR3s
#   processed 19000 CDR3s
#   processed 19100 CDR3s
#   processed 19200 CDR3s
#   processed 19300 CDR3s
#   processed 19400 CDR3s
#   processed 19500 CDR3s
#   processed 19600 CDR3s
#   processed 19700 CDR3s
#   processed 19800 CDR3s
#   processed 19900 CDR3s
#   processed 20000 CDR3s
#   processed 20100 CDR3s
#   processed 20200 CDR3s
#   processed 20300 CDR3s
#   processed 20400 CDR3s
#   processed 20500 CDR3s
#   processed 20600 CDR3s
#   processed 20700 CDR3s
#   processed 20800 CDR3s
#   processed 20900 CDR3s
#   processed 21000 CDR3s
#   processed 21100 CDR3s
#   processed 21200 CDR3s
#   processed 21300 CDR3s
#   processed 21400 CDR3s
#   processed 21500 CDR3s
#   processed 21600 CDR3s
#   processed 21700 CDR3s
#   processed 21800 CDR3s
#   processed 21900 CDR3s
#   processed 22000 CDR3s
#   processed 22100 CDR3s
#   processed 22200 CDR3s
#   processed 22300 CDR3s
#   processed 22400 CDR3s
#   processed 22500 CDR3s
#   processed 22600 CDR3s
#   processed 22700 CDR3s
#   processed 22800 CDR3s
#   processed 22900 CDR3s
#   processed 23000 CDR3s
#   processed 23100 CDR3s
#   processed 23200 CDR3s
#   processed 23300 CDR3s
#   processed 23400 CDR3s
#   processed 23500 CDR3s
#   processed 23600 CDR3s
#   processed 23700 CDR3s
#   processed 23800 CDR3s
#   processed 23900 CDR3s
#   processed 24000 CDR3s
#   processed 24100 CDR3s
#   processed 24200 CDR3s
#   processed 24300 CDR3s
#   processed 24400 CDR3s
#   processed 24500 CDR3s
#   processed 24600 CDR3s
#   processed 24700 CDR3s
#   processed 24800 CDR3s
#   processed 24900 CDR3s
#   processed 25000 CDR3s
#   processed 25100 CDR3s
#   processed 25200 CDR3s
#   processed 25300 CDR3s
#   processed 25400 CDR3s
#   processed 25500 CDR3s
#   processed 25600 CDR3s
#   processed 25700 CDR3s
#   processed 25800 CDR3s
#   processed 25900 CDR3s
#   processed 26000 CDR3s
#   processed 26100 CDR3s
#   processed 26200 CDR3s
#   processed 26300 CDR3s
#   processed 26400 CDR3s
#   processed 26500 CDR3s
#   processed 26600 CDR3s
#   processed 26700 CDR3s
#   processed 26800 CDR3s
#   processed 26900 CDR3s
#   processed 27000 CDR3s
#   processed 27100 CDR3s
#   processed 27200 CDR3s
#   processed 27300 CDR3s
#   processed 27400 CDR3s
#   processed 27500 CDR3s
#   processed 27600 CDR3s
#   processed 27700 CDR3s
#   processed 27800 CDR3s
#   processed 27900 CDR3s
#   processed 28000 CDR3s
#   processed 28100 CDR3s
#   processed 28200 CDR3s
#   processed 28300 CDR3s
#   processed 28400 CDR3s
#   processed 28500 CDR3s
#   processed 28600 CDR3s
#   processed 28700 CDR3s
#   processed 28800 CDR3s
#   processed 28900 CDR3s
#   processed 29000 CDR3s
#   processed 29100 CDR3s
#   processed 29200 CDR3s
#   processed 29300 CDR3s
#   processed 29400 CDR3s
#   processed 29500 CDR3s
#   processed 29600 CDR3s
#   processed 29700 CDR3s
#   processed 29800 CDR3s
#   processed 29900 CDR3s
#   processed 30000 CDR3s
#   processed 30100 CDR3s
#   processed 30200 CDR3s
#   processed 30300 CDR3s
#   processed 30400 CDR3s
#   processed 30500 CDR3s
#   processed 30600 CDR3s
#   processed 30700 CDR3s
#   processed 30800 CDR3s
#   processed 30900 CDR3s
#   processed 31000 CDR3s
#   processed 31100 CDR3s
#   processed 31200 CDR3s
#   processed 31300 CDR3s
#   processed 31400 CDR3s
#   processed 31500 CDR3s
#   processed 31600 CDR3s
#   processed 31700 CDR3s
#   processed 31800 CDR3s
#   processed 31900 CDR3s
#   processed 32000 CDR3s
#   processed 32100 CDR3s
#   processed 32200 CDR3s
#   processed 32300 CDR3s
#   processed 32400 CDR3s
#   processed 32500 CDR3s
#   processed 32600 CDR3s
#   processed 32700 CDR3s
#   processed 32800 CDR3s
#   processed 32900 CDR3s
#   processed 33000 CDR3s
#   processed 33100 CDR3s
#   processed 33200 CDR3s
#   processed 33300 CDR3s
#   processed 33400 CDR3s
#   processed 33500 CDR3s
#   processed 33600 CDR3s
#   processed 33700 CDR3s
#   processed 33800 CDR3s
#   processed 33900 CDR3s
#   processed 34000 CDR3s
#   processed 34100 CDR3s
#   processed 34200 CDR3s
#   processed 34300 CDR3s
#   processed 34400 CDR3s
#   processed 34500 CDR3s
#   processed 34600 CDR3s
#   processed 34700 CDR3s
#   processed 34800 CDR3s
#   processed 34900 CDR3s
#   processed 35000 CDR3s
#   processed 35100 CDR3s
#   processed 35200 CDR3s
#   processed 35300 CDR3s
#   processed 35400 CDR3s
#   processed 35500 CDR3s
#   processed 35600 CDR3s
#   processed 35700 CDR3s
#   processed 35800 CDR3s
#   processed 35900 CDR3s
#   processed 36000 CDR3s
#   processed 36100 CDR3s
#   processed 36200 CDR3s
#   processed 36300 CDR3s
#   processed 36400 CDR3s
#   processed 36500 CDR3s
#   processed 36600 CDR3s
#   processed 36700 CDR3s
#   processed 36800 CDR3s
#   processed 36900 CDR3s
#   processed 37000 CDR3s
#   processed 37100 CDR3s
#   processed 37200 CDR3s
#   processed 37300 CDR3s
#   processed 37400 CDR3s
#   processed 37500 CDR3s
#   processed 37600 CDR3s
#   processed 37700 CDR3s
#   processed 37800 CDR3s
#   processed 37900 CDR3s
#   processed 38000 CDR3s
#   processed 38100 CDR3s
#   processed 38200 CDR3s
#   processed 38300 CDR3s
#   processed 38400 CDR3s
#   processed 38500 CDR3s
#   processed 38600 CDR3s
#   processed 38700 CDR3s
#   processed 38800 CDR3s
#   processed 38900 CDR3s
#   processed 39000 CDR3s
#   processed 39100 CDR3s
#   processed 39200 CDR3s
#   processed 39300 CDR3s
#   processed 39400 CDR3s
#   processed 39500 CDR3s
#   processed 39600 CDR3s
#   processed 39700 CDR3s
#   processed 39800 CDR3s
#   processed 39900 CDR3s
#   processed 40000 CDR3s
#   processed 40100 CDR3s
#   processed 40200 CDR3s
#   processed 40300 CDR3s
#   processed 40400 CDR3s
#   processed 40500 CDR3s
#   processed 40600 CDR3s
#   processed 40700 CDR3s
#   processed 40800 CDR3s
#   processed 40900 CDR3s
#   processed 41000 CDR3s
#   processed 41100 CDR3s
#   processed 41200 CDR3s
#   processed 41300 CDR3s
#   processed 41400 CDR3s
#   processed 41500 CDR3s
#   processed 41600 CDR3s
#   processed 41700 CDR3s
#   processed 41800 CDR3s
#   processed 41900 CDR3s
#   processed 42000 CDR3s
#   processed 42100 CDR3s
#   processed 42200 CDR3s
#   processed 42300 CDR3s
#   processed 42400 CDR3s
#   processed 42500 CDR3s
#   processed 42600 CDR3s
#   processed 42700 CDR3s
#   processed 42800 CDR3s
#   processed 42900 CDR3s
#   processed 43000 CDR3s
#   processed 43100 CDR3s
#   processed 43200 CDR3s
#   processed 43300 CDR3s
#   processed 43400 CDR3s
#   processed 43500 CDR3s
#   processed 43600 CDR3s
#   processed 43700 CDR3s
#   processed 43800 CDR3s
#   processed 43900 CDR3s
#   processed 44000 CDR3s
#   processed 44100 CDR3s
#   processed 44200 CDR3s
#   processed 44300 CDR3s
#   processed 44400 CDR3s
#   processed 44500 CDR3s
#   processed 44600 CDR3s
#   processed 44700 CDR3s
#   processed 44800 CDR3s
#   processed 44900 CDR3s
#   processed 45000 CDR3s
#   processed 45100 CDR3s
#   processed 45200 CDR3s
#   processed 45300 CDR3s
#   processed 45400 CDR3s
#   processed 45500 CDR3s
#   processed 45600 CDR3s
#   processed 45700 CDR3s
#   processed 45800 CDR3s
#   processed 45900 CDR3s
#   processed 46000 CDR3s
#   processed 46100 CDR3s
#   processed 46200 CDR3s
#   processed 46300 CDR3s
#   processed 46400 CDR3s
#   processed 46500 CDR3s
#   processed 46600 CDR3s
#   processed 46700 CDR3s
#   processed 46800 CDR3s
#   processed 46900 CDR3s
#   processed 47000 CDR3s
#   processed 47100 CDR3s
#   processed 47200 CDR3s
#   processed 47300 CDR3s
#   processed 47400 CDR3s
#   processed 47500 CDR3s
#   processed 47600 CDR3s
#   processed 47700 CDR3s
#   processed 47800 CDR3s
#   processed 47900 CDR3s
#   processed 48000 CDR3s
#   processed 48100 CDR3s
#   processed 48200 CDR3s
#   processed 48300 CDR3s
#   processed 48400 CDR3s
#   processed 48500 CDR3s
#   processed 48600 CDR3s
#   processed 48700 CDR3s
#   processed 48800 CDR3s
#   processed 48900 CDR3s
#   processed 49000 CDR3s
#   processed 49100 CDR3s
#   processed 49200 CDR3s
#   processed 49300 CDR3s
#   processed 49400 CDR3s
#   processed 49500 CDR3s
#   processed 49600 CDR3s
#   processed 49700 CDR3s
#   processed 49800 CDR3s
#   processed 49900 CDR3s
#   processed 50000 CDR3s
#   processed 50100 CDR3s
#   processed 50200 CDR3s
#   processed 50300 CDR3s
#   processed 50400 CDR3s
#   processed 50500 CDR3s
#   processed 50600 CDR3s
#   processed 50700 CDR3s
#   processed 50800 CDR3s
#   processed 50900 CDR3s
#   processed 51000 CDR3s
#   processed 51100 CDR3s
#   processed 51200 CDR3s
#   processed 51300 CDR3s
#   processed 51400 CDR3s
#   processed 51500 CDR3s
#   processed 51600 CDR3s
#   processed 51700 CDR3s
#   processed 51800 CDR3s
#   processed 51900 CDR3s
#   processed 52000 CDR3s
#   processed 52100 CDR3s
#   processed 52200 CDR3s
#   processed 52300 CDR3s
#   processed 52400 CDR3s
#   processed 52500 CDR3s
#   processed 52600 CDR3s
#   processed 52700 CDR3s
#   processed 52800 CDR3s
#   processed 52900 CDR3s
#   processed 53000 CDR3s
#   processed 53100 CDR3s
#   processed 53200 CDR3s
#   processed 53300 CDR3s
#   processed 53400 CDR3s
#   processed 53500 CDR3s
#   processed 53600 CDR3s
#   processed 53700 CDR3s
#   processed 53800 CDR3s
#   processed 53900 CDR3s
#   processed 54000 CDR3s
#   processed 54100 CDR3s
#   processed 54200 CDR3s
#   processed 54300 CDR3s
#   processed 54400 CDR3s
#   processed 54500 CDR3s
#   processed 54600 CDR3s
#   processed 54700 CDR3s
#   processed 54800 CDR3s
#   processed 54900 CDR3s
#   processed 55000 CDR3s
#   processed 55100 CDR3s
#   processed 55200 CDR3s
#   processed 55300 CDR3s
#   processed 55400 CDR3s
#   processed 55500 CDR3s
#   processed 55600 CDR3s
#   processed 55700 CDR3s
#   processed 55800 CDR3s
#   processed 55900 CDR3s
#   processed 56000 CDR3s
#   processed 56100 CDR3s
#   processed 56200 CDR3s
#   processed 56300 CDR3s
#   processed 56400 CDR3s
#   processed 56500 CDR3s
#   processed 56600 CDR3s
#   processed 56700 CDR3s
#   processed 56800 CDR3s
#   processed 56900 CDR3s
#   processed 57000 CDR3s
#   processed 57100 CDR3s
#   processed 57200 CDR3s
#   processed 57300 CDR3s
#   processed 57400 CDR3s
#   processed 57500 CDR3s
#   processed 57600 CDR3s
#   processed 57700 CDR3s
#   processed 57800 CDR3s
#   processed 57900 CDR3s
#   processed 58000 CDR3s
#   processed 58100 CDR3s
#   processed 58200 CDR3s
#   processed 58300 CDR3s
#   processed 58400 CDR3s
#   processed 58500 CDR3s
#   processed 58600 CDR3s
#   processed 58700 CDR3s
#   processed 58800 CDR3s
#   processed 58900 CDR3s
#   processed 59000 CDR3s
#   processed 59100 CDR3s
#   processed 59200 CDR3s
#   processed 59300 CDR3s
#   processed 59400 CDR3s
#   processed 59500 CDR3s
#   processed 59600 CDR3s
#   processed 59700 CDR3s
#   processed 59800 CDR3s
#   processed 59900 CDR3s
#   processed 60000 CDR3s
#   processed 60100 CDR3s
#   processed 60200 CDR3s
#   processed 60300 CDR3s
#   processed 60400 CDR3s
#   processed 60500 CDR3s
#   processed 60600 CDR3s
#   processed 60700 CDR3s
#   processed 60800 CDR3s
#   processed 60900 CDR3s
#   processed 61000 CDR3s
#   processed 61100 CDR3s
#   processed 61200 CDR3s
#   processed 61300 CDR3s
#   processed 61400 CDR3s
#   processed 61500 CDR3s
#   processed 61600 CDR3s
#   processed 61700 CDR3s
#   processed 61800 CDR3s
#   processed 61900 CDR3s
#   processed 62000 CDR3s
#   processed 62100 CDR3s
#   processed 62200 CDR3s
#   processed 62300 CDR3s
#   processed 62400 CDR3s
#   processed 62500 CDR3s
#   processed 62600 CDR3s
#   processed 62700 CDR3s
#   processed 62800 CDR3s
#   processed 62900 CDR3s
#   processed 63000 CDR3s
#   processed 63100 CDR3s
#   processed 63200 CDR3s
#   processed 63300 CDR3s
#   processed 63400 CDR3s
#   processed 63500 CDR3s
#   processed 63600 CDR3s
#   processed 63700 CDR3s
#   processed 63800 CDR3s
#   processed 63900 CDR3s
#   processed 64000 CDR3s
#   processed 64100 CDR3s
#   processed 64200 CDR3s
#   processed 64300 CDR3s
#   processed 64400 CDR3s
#   processed 64500 CDR3s
#   processed 64600 CDR3s
#   processed 64700 CDR3s
#   processed 64800 CDR3s
#   processed 64900 CDR3s
#   processed 65000 CDR3s
#   processed 65100 CDR3s
#   processed 65200 CDR3s
#   processed 65300 CDR3s
#   processed 65400 CDR3s
#   processed 65500 CDR3s
#   processed 65600 CDR3s
#   processed 65700 CDR3s
#   processed 65800 CDR3s
#   processed 65900 CDR3s
#   processed 66000 CDR3s
#   processed 66100 CDR3s
#   processed 66200 CDR3s
#   processed 66300 CDR3s
#   processed 66400 CDR3s
#   processed 66500 CDR3s
#   processed 66600 CDR3s
#   processed 66700 CDR3s
#   processed 66800 CDR3s
#   processed 66900 CDR3s
#   processed 67000 CDR3s
#   processed 67100 CDR3s
#   processed 67200 CDR3s
#   processed 67300 CDR3s
#   processed 67400 CDR3s
#   processed 67500 CDR3s
#   processed 67600 CDR3s
#   processed 67700 CDR3s
#   processed 67800 CDR3s
#   processed 67900 CDR3s
#   processed 68000 CDR3s
#   processed 68100 CDR3s
#   processed 68200 CDR3s
#   processed 68300 CDR3s
#   processed 68400 CDR3s
#   processed 68500 CDR3s
#   processed 68600 CDR3s
#   processed 68700 CDR3s
#   processed 68800 CDR3s
#   processed 68900 CDR3s
#   processed 69000 CDR3s
#   processed 69100 CDR3s
#   processed 69200 CDR3s
#   processed 69300 CDR3s
#   processed 69400 CDR3s
#   processed 69500 CDR3s
#   processed 69600 CDR3s
#   processed 69700 CDR3s
#   processed 69800 CDR3s
#   processed 69900 CDR3s
#   processed 70000 CDR3s
#   processed 70100 CDR3s
#   processed 70200 CDR3s
#   processed 70300 CDR3s
#   processed 70400 CDR3s
#   processed 70500 CDR3s
#   processed 70600 CDR3s
#   processed 70700 CDR3s
#   processed 70800 CDR3s
#   processed 70900 CDR3s
#   processed 71000 CDR3s
#   processed 71100 CDR3s
#   processed 71200 CDR3s
#   processed 71300 CDR3s
#   processed 71400 CDR3s
#   processed 71500 CDR3s
#   processed 71600 CDR3s
#   processed 71700 CDR3s
#   processed 71800 CDR3s
#   processed 71900 CDR3s
#   processed 72000 CDR3s
#   processed 72100 CDR3s
#   processed 72200 CDR3s
#   processed 72300 CDR3s
#   processed 72400 CDR3s
#   processed 72500 CDR3s
#   processed 72600 CDR3s
#   processed 72700 CDR3s
#   processed 72800 CDR3s
#   processed 72900 CDR3s
#   processed 73000 CDR3s
#   processed 73100 CDR3s
#   processed 73200 CDR3s
#   processed 73300 CDR3s
#   processed 73400 CDR3s
#   processed 73500 CDR3s
#   processed 73600 CDR3s
#   processed 73700 CDR3s
#   processed 73800 CDR3s
#   processed 73900 CDR3s
#   processed 74000 CDR3s
#   processed 74100 CDR3s
#   processed 74200 CDR3s
#   processed 74300 CDR3s
#   processed 74400 CDR3s
#   processed 74500 CDR3s
#   processed 74600 CDR3s
#   processed 74700 CDR3s
#   processed 74800 CDR3s
#   processed 74900 CDR3s
#   processed 75000 CDR3s
#   processed 75100 CDR3s
#   processed 75200 CDR3s
#   processed 75300 CDR3s
#   processed 75400 CDR3s
#   processed 75500 CDR3s
#   processed 75600 CDR3s
#   processed 75700 CDR3s
#   processed 75800 CDR3s
#   processed 75900 CDR3s
#   processed 76000 CDR3s
#   processed 76100 CDR3s
#   processed 76200 CDR3s
#   processed 76300 CDR3s
#   processed 76400 CDR3s
#   processed 76500 CDR3s
#   processed 76600 CDR3s
#   processed 76700 CDR3s
#   processed 76800 CDR3s
#   processed 76900 CDR3s
#   processed 77000 CDR3s
#   processed 77100 CDR3s
#   processed 77200 CDR3s
#   processed 77300 CDR3s
#   processed 77400 CDR3s
#   processed 77500 CDR3s
#   processed 77600 CDR3s
#   processed 77700 CDR3s
#   processed 77800 CDR3s
#   processed 77900 CDR3s
#   processed 78000 CDR3s
#   processed 78100 CDR3s
#   processed 78200 CDR3s
#   processed 78300 CDR3s
#   processed 78400 CDR3s
#   processed 78500 CDR3s
#   processed 78600 CDR3s
#   processed 78700 CDR3s
#   processed 78800 CDR3s
#   processed 78900 CDR3s
#   processed 79000 CDR3s
#   processed 79100 CDR3s
#   processed 79200 CDR3s
#   processed 79300 CDR3s
#   processed 79400 CDR3s
#   processed 79500 CDR3s
#   processed 79600 CDR3s
#   processed 79700 CDR3s
#   processed 79800 CDR3s
#   processed 79900 CDR3s
#   processed 80000 CDR3s
#   processed 80100 CDR3s
#   processed 80200 CDR3s
#   processed 80300 CDR3s
#   processed 80400 CDR3s
#   processed 80500 CDR3s
#   processed 80600 CDR3s
#   processed 80700 CDR3s
#   processed 80800 CDR3s
#   processed 80900 CDR3s
#   processed 81000 CDR3s
#   processed 81100 CDR3s
#   processed 81200 CDR3s
#   processed 81300 CDR3s
#   processed 81400 CDR3s
#   processed 81500 CDR3s
#   processed 81600 CDR3s
#   processed 81700 CDR3s
#   processed 81800 CDR3s
#   processed 81900 CDR3s
#   processed 82000 CDR3s
#   processed 82100 CDR3s
#   processed 82200 CDR3s
#   processed 82300 CDR3s
#   processed 82400 CDR3s
#   processed 82500 CDR3s
#   processed 82600 CDR3s
#   processed 82700 CDR3s
#   processed 82800 CDR3s
#   processed 82900 CDR3s
#   processed 83000 CDR3s
#   processed 83100 CDR3s
#   processed 83200 CDR3s
#   processed 83300 CDR3s
#   processed 83400 CDR3s
#   processed 83500 CDR3s
#   processed 83600 CDR3s
#   processed 83700 CDR3s
#   processed 83800 CDR3s
#   processed 83900 CDR3s
#   processed 84000 CDR3s
#   processed 84100 CDR3s
#   processed 84200 CDR3s
#   processed 84300 CDR3s
#   processed 84400 CDR3s
#   processed 84500 CDR3s
#   processed 84600 CDR3s
#   processed 84700 CDR3s
#   processed 84800 CDR3s
#   processed 84900 CDR3s
#   processed 85000 CDR3s
#   processed 85100 CDR3s
#   processed 85200 CDR3s
#   processed 85300 CDR3s
#   processed 85400 CDR3s
#   processed 85500 CDR3s
#   processed 85600 CDR3s
#   processed 85700 CDR3s
#   processed 85800 CDR3s
#   processed 85900 CDR3s
#   processed 86000 CDR3s
#   processed 86100 CDR3s
#   processed 86200 CDR3s
#   processed 86300 CDR3s
#   processed 86400 CDR3s
#   processed 86500 CDR3s
#   processed 86600 CDR3s
#   processed 86700 CDR3s
#   processed 86800 CDR3s
#   processed 86900 CDR3s
#   processed 87000 CDR3s
#   processed 87100 CDR3s
#   processed 87200 CDR3s
#   processed 87300 CDR3s
#   processed 87400 CDR3s
#   processed 87500 CDR3s
#   processed 87600 CDR3s
#   processed 87700 CDR3s
#   processed 87800 CDR3s
#   processed 87900 CDR3s
#   processed 88000 CDR3s
#   processed 88100 CDR3s
#   processed 88200 CDR3s
#   processed 88300 CDR3s
#   processed 88400 CDR3s
#   processed 88500 CDR3s
#   processed 88600 CDR3s
#   processed 88700 CDR3s
#   processed 88800 CDR3s
#   processed 88900 CDR3s
#   processed 89000 CDR3s
#   processed 89100 CDR3s
#   processed 89200 CDR3s
#   processed 89300 CDR3s
#   processed 89400 CDR3s
#   processed 89500 CDR3s
#   processed 89600 CDR3s
#   processed 89700 CDR3s
#   processed 89800 CDR3s
#   processed 89900 CDR3s
#   processed 90000 CDR3s
#   processed 90100 CDR3s
#   processed 90200 CDR3s
#   processed 90300 CDR3s
#   processed 90400 CDR3s
#   processed 90500 CDR3s
#   processed 90600 CDR3s
#   processed 90700 CDR3s
#   processed 90800 CDR3s
#   processed 90900 CDR3s
#   processed 91000 CDR3s
#   processed 91100 CDR3s
#   processed 91200 CDR3s
#   processed 91300 CDR3s
#   processed 91400 CDR3s
#   processed 91500 CDR3s
#   processed 91600 CDR3s
#   processed 91700 CDR3s
#   processed 91800 CDR3s
#   processed 91900 CDR3s
#   processed 92000 CDR3s
#   processed 92100 CDR3s
#   processed 92200 CDR3s
#   processed 92300 CDR3s
#   processed 92400 CDR3s
#   processed 92500 CDR3s
#   processed 92600 CDR3s
#   processed 92700 CDR3s
#   processed 92800 CDR3s
#   processed 92900 CDR3s
#   processed 93000 CDR3s
#   processed 93100 CDR3s
#   processed 93200 CDR3s
#   processed 93300 CDR3s
#   processed 93400 CDR3s
#   processed 93500 CDR3s
#   processed 93600 CDR3s
#   processed 93700 CDR3s
#   processed 93800 CDR3s
#   processed 93900 CDR3s
#   processed 94000 CDR3s
#   processed 94100 CDR3s
#   processed 94200 CDR3s
#   processed 94300 CDR3s
#   processed 94400 CDR3s
#   processed 94500 CDR3s
#   processed 94600 CDR3s
#   processed 94700 CDR3s
#   processed 94800 CDR3s
#   processed 94900 CDR3s
#   processed 95000 CDR3s
#   processed 95100 CDR3s
#   processed 95200 CDR3s
#   processed 95300 CDR3s
#   processed 95400 CDR3s
#   processed 95500 CDR3s
#   processed 95600 CDR3s
#   processed 95700 CDR3s
#   processed 95800 CDR3s
#   processed 95900 CDR3s
#   processed 96000 CDR3s
#   processed 96100 CDR3s
#   processed 96200 CDR3s
#   processed 96300 CDR3s
#   processed 96400 CDR3s
#   processed 96500 CDR3s
#   processed 96600 CDR3s
#   processed 96700 CDR3s
#   processed 96800 CDR3s
#   processed 96900 CDR3s
#   processed 97000 CDR3s
#   processed 97100 CDR3s
#   processed 97200 CDR3s
#   processed 97300 CDR3s
#   processed 97400 CDR3s
#   processed 97500 CDR3s
#   processed 97600 CDR3s
#   processed 97700 CDR3s
#   processed 97800 CDR3s
#   processed 97900 CDR3s
#   processed 98000 CDR3s
#   processed 98100 CDR3s
#   processed 98200 CDR3s
#   processed 98300 CDR3s
#   processed 98400 CDR3s
#   processed 98500 CDR3s
#   processed 98600 CDR3s
#   processed 98700 CDR3s
#   processed 98800 CDR3s
#   processed 98900 CDR3s
#   processed 99000 CDR3s
#   processed 99100 CDR3s
#   processed 99200 CDR3s
#   processed 99300 CDR3s
#   processed 99400 CDR3s
#   processed 99500 CDR3s
#   processed 99600 CDR3s
#   processed 99700 CDR3s
#   processed 99800 CDR3s
#   processed 99900 CDR3s
#   processed 100000 CDR3s
#   processed 100100 CDR3s
#   processed 100200 CDR3s
#   processed 100300 CDR3s
#   processed 100400 CDR3s
#   processed 100500 CDR3s
#   processed 100600 CDR3s
#   processed 100700 CDR3s
#   processed 100800 CDR3s
#   processed 100900 CDR3s
#   processed 101000 CDR3s
#   processed 101100 CDR3s
#   processed 101200 CDR3s
#   processed 101300 CDR3s
#   processed 101400 CDR3s
#   processed 101500 CDR3s
#   processed 101600 CDR3s
#   processed 101700 CDR3s
#   processed 101800 CDR3s
#   processed 101900 CDR3s
#   processed 102000 CDR3s
#   processed 102100 CDR3s
#   processed 102200 CDR3s
#   processed 102300 CDR3s
#   processed 102400 CDR3s
#   processed 102500 CDR3s
#   processed 102600 CDR3s
#   processed 102700 CDR3s
#   processed 102800 CDR3s
#   processed 102900 CDR3s
#   processed 103000 CDR3s
#   processed 103100 CDR3s
#   processed 103200 CDR3s
#   processed 103300 CDR3s
#   processed 103400 CDR3s
#   processed 103500 CDR3s
#   processed 103600 CDR3s
#   processed 103700 CDR3s
#   processed 103800 CDR3s
#   processed 103900 CDR3s
#   processed 104000 CDR3s
#   processed 104100 CDR3s
#   processed 104200 CDR3s
#   processed 104300 CDR3s
#   processed 104400 CDR3s
#   processed 104500 CDR3s
#   processed 104600 CDR3s
#   processed 104700 CDR3s
#   processed 104800 CDR3s
#   processed 104900 CDR3s
#   processed 105000 CDR3s
#   processed 105100 CDR3s
#   processed 105200 CDR3s
#   processed 105300 CDR3s
#   processed 105400 CDR3s
#   processed 105500 CDR3s
#   processed 105600 CDR3s
#   processed 105700 CDR3s
#   processed 105800 CDR3s
#   processed 105900 CDR3s
#   processed 106000 CDR3s
#   processed 106100 CDR3s
#   processed 106200 CDR3s
#   processed 106300 CDR3s
#   processed 106400 CDR3s
#   processed 106500 CDR3s
#   processed 106600 CDR3s
#   processed 106700 CDR3s
#   processed 106800 CDR3s
#   processed 106900 CDR3s
#   processed 107000 CDR3s
#   processed 107100 CDR3s
#   processed 107200 CDR3s
#   processed 107300 CDR3s
#   processed 107400 CDR3s
#   processed 107500 CDR3s
#   processed 107600 CDR3s
#   processed 107700 CDR3s
#   processed 107800 CDR3s
#   processed 107900 CDR3s
#   processed 108000 CDR3s
#   processed 108100 CDR3s
#   processed 108200 CDR3s
#   processed 108300 CDR3s
#   processed 108400 CDR3s
#   processed 108500 CDR3s
#   processed 108600 CDR3s
#   processed 108700 CDR3s
#   processed 108800 CDR3s
#   processed 108900 CDR3s
#   processed 109000 CDR3s
#   processed 109100 CDR3s
#   processed 109200 CDR3s
#   processed 109300 CDR3s
#   processed 109400 CDR3s
#   processed 109500 CDR3s
#   processed 109600 CDR3s
#   processed 109700 CDR3s
#   processed 109800 CDR3s
#   processed 109900 CDR3s
#   processed 110000 CDR3s
#   processed 110100 CDR3s
#   processed 110200 CDR3s
#   processed 110300 CDR3s
#   processed 110400 CDR3s
#   processed 110500 CDR3s
#   processed 110600 CDR3s
#   processed 110700 CDR3s
#   processed 110800 CDR3s
#   processed 110900 CDR3s
#   processed 111000 CDR3s
#   processed 111100 CDR3s
#   processed 111200 CDR3s
#   processed 111300 CDR3s
#   processed 111400 CDR3s
#   processed 111500 CDR3s
#   processed 111600 CDR3s
#   processed 111700 CDR3s
#   processed 111800 CDR3s
#   processed 111900 CDR3s
#   processed 112000 CDR3s
#   processed 112100 CDR3s
#   processed 112200 CDR3s
#   processed 112300 CDR3s
#   processed 112400 CDR3s
#   processed 112500 CDR3s
#   processed 112600 CDR3s
#   processed 112700 CDR3s
#   processed 112800 CDR3s
#   processed 112900 CDR3s
#   processed 113000 CDR3s
#   processed 113100 CDR3s
#   processed 113200 CDR3s
#   processed 113300 CDR3s
#   processed 113400 CDR3s
#   processed 113500 CDR3s
#   processed 113600 CDR3s
#   processed 113700 CDR3s
#   processed 113800 CDR3s
#   processed 113900 CDR3s
#   processed 114000 CDR3s
#   processed 114100 CDR3s
#   processed 114200 CDR3s
#   processed 114300 CDR3s
#   processed 114400 CDR3s
#   processed 114500 CDR3s
#   processed 114600 CDR3s
#   processed 114700 CDR3s
#   processed 114800 CDR3s
#   processed 114900 CDR3s
#   processed 115000 CDR3s
#   processed 115100 CDR3s
#   processed 115200 CDR3s
#   processed 115300 CDR3s
#   processed 115400 CDR3s
#   processed 115500 CDR3s
#   processed 115600 CDR3s
#   processed 115700 CDR3s
#   processed 115800 CDR3s
#   processed 115900 CDR3s
#   processed 116000 CDR3s
#   processed 116100 CDR3s
#   processed 116200 CDR3s
#   processed 116300 CDR3s
#   processed 116400 CDR3s
#   processed 116500 CDR3s
#   processed 116600 CDR3s
#   processed 116700 CDR3s
#   processed 116800 CDR3s
#   processed 116900 CDR3s
#   processed 117000 CDR3s
#   processed 117100 CDR3s
#   processed 117200 CDR3s
#   processed 117300 CDR3s
#   processed 117400 CDR3s
#   processed 117500 CDR3s
#   processed 117600 CDR3s
#   processed 117700 CDR3s
#   processed 117800 CDR3s
#   processed 117900 CDR3s
#   processed 118000 CDR3s
#   processed 118100 CDR3s
#   processed 118200 CDR3s
#   processed 118300 CDR3s
#   processed 118400 CDR3s
#   processed 118500 CDR3s
#   processed 118600 CDR3s
#   processed 118700 CDR3s
#   processed 118800 CDR3s
#   processed 118900 CDR3s
#   processed 119000 CDR3s
#   processed 119100 CDR3s
#   processed 119200 CDR3s
#   processed 119300 CDR3s
#   processed 119400 CDR3s
#   processed 119500 CDR3s
#   processed 119600 CDR3s
#   processed 119700 CDR3s
#   processed 119800 CDR3s
#   processed 119900 CDR3s
#   processed 120000 CDR3s
#   processed 120100 CDR3s
#   processed 120200 CDR3s
#   processed 120300 CDR3s
#   processed 120400 CDR3s
#   processed 120500 CDR3s
#   processed 120600 CDR3s
#   processed 120700 CDR3s
#   processed 120800 CDR3s
#   processed 120900 CDR3s
#   processed 121000 CDR3s
#   processed 121100 CDR3s
#   processed 121200 CDR3s
#   processed 121300 CDR3s
#   processed 121400 CDR3s
#   processed 121500 CDR3s
#   processed 121600 CDR3s
#   processed 121700 CDR3s
#   processed 121800 CDR3s
#   processed 121900 CDR3s
#   processed 122000 CDR3s
#   processed 122100 CDR3s
#   processed 122200 CDR3s
#   processed 122300 CDR3s
#   processed 122400 CDR3s
#   processed 122500 CDR3s
#   processed 122600 CDR3s
#   processed 122700 CDR3s
#   processed 122800 CDR3s
#   processed 122900 CDR3s
#   processed 123000 CDR3s
#   processed 123100 CDR3s
#   processed 123200 CDR3s
#   processed 123300 CDR3s
#   processed 123400 CDR3s
#   processed 123500 CDR3s
#   processed 123600 CDR3s
#   processed 123700 CDR3s
#   processed 123800 CDR3s
#   processed 123900 CDR3s
#   processed 124000 CDR3s
#   processed 124100 CDR3s
#   processed 124200 CDR3s
#   processed 124300 CDR3s
#   processed 124400 CDR3s
#   processed 124500 CDR3s
#   processed 124600 CDR3s
#   processed 124700 CDR3s
#   processed 124800 CDR3s
#   processed 124900 CDR3s
#   processed 125000 CDR3s
#   processed 125100 CDR3s
#   processed 125200 CDR3s
#   processed 125300 CDR3s
#   processed 125400 CDR3s
#   processed 125500 CDR3s
#   processed 125600 CDR3s
#   processed 125700 CDR3s
#   processed 125800 CDR3s
#   processed 125900 CDR3s
#   processed 126000 CDR3s
#   processed 126100 CDR3s
#   processed 126200 CDR3s
#   processed 126300 CDR3s
#   processed 126400 CDR3s
#   processed 126500 CDR3s
#   processed 126600 CDR3s
#   processed 126700 CDR3s
#   processed 126800 CDR3s
#   processed 126900 CDR3s
#   processed 127000 CDR3s
#   processed 127100 CDR3s
#   processed 127200 CDR3s
#   processed 127300 CDR3s
#   processed 127400 CDR3s
#   processed 127500 CDR3s
#   processed 127600 CDR3s
#   processed 127700 CDR3s
#   processed 127800 CDR3s
#   processed 127900 CDR3s
#   processed 128000 CDR3s
#   processed 128100 CDR3s
#   processed 128200 CDR3s
#   processed 128300 CDR3s
#   processed 128400 CDR3s
#   processed 128500 CDR3s
#   processed 128600 CDR3s
#   processed 128700 CDR3s
#   processed 128800 CDR3s
#   processed 128900 CDR3s
#   processed 129000 CDR3s
#   processed 129100 CDR3s
#   processed 129200 CDR3s
#   processed 129300 CDR3s
#   processed 129400 CDR3s
#   processed 129500 CDR3s
#   processed 129600 CDR3s
#   processed 129700 CDR3s
#   processed 129800 CDR3s
#   processed 129900 CDR3s
#   processed 130000 CDR3s
#   processed 130100 CDR3s
#   processed 130200 CDR3s
#   processed 130300 CDR3s
#   processed 130400 CDR3s
#   processed 130500 CDR3s
#   processed 130600 CDR3s
#   processed 130700 CDR3s
#   processed 130800 CDR3s
#   processed 130900 CDR3s
#   processed 131000 CDR3s
#   processed 131100 CDR3s
#   processed 131200 CDR3s
#   processed 131300 CDR3s
#   processed 131400 CDR3s
#   processed 131500 CDR3s
#   processed 131600 CDR3s
#   processed 131700 CDR3s
#   processed 131800 CDR3s
#   processed 131900 CDR3s
#   processed 132000 CDR3s
#   processed 132100 CDR3s
#   processed 132200 CDR3s
#   processed 132300 CDR3s
#   processed 132400 CDR3s
#   processed 132500 CDR3s
#   processed 132600 CDR3s
#   processed 132700 CDR3s
#   processed 132800 CDR3s
#   processed 132900 CDR3s
#   processed 133000 CDR3s
#   processed 133100 CDR3s
#   processed 133200 CDR3s
#   processed 133300 CDR3s
#   processed 133400 CDR3s
#   processed 133500 CDR3s
#   processed 133600 CDR3s
#   processed 133700 CDR3s
#   processed 133800 CDR3s
#   processed 133900 CDR3s
#   processed 134000 CDR3s
#   processed 134100 CDR3s
#   processed 134200 CDR3s
#   processed 134300 CDR3s
#   processed 134400 CDR3s
#   processed 134500 CDR3s
#   processed 134600 CDR3s
#   processed 134700 CDR3s
#   processed 134800 CDR3s
#   processed 134900 CDR3s
#   processed 135000 CDR3s
#   processed 135100 CDR3s
#   processed 135200 CDR3s
#   processed 135300 CDR3s
#   processed 135400 CDR3s
#   processed 135500 CDR3s
#   processed 135600 CDR3s
#   processed 135700 CDR3s
#   processed 135800 CDR3s
#   processed 135900 CDR3s
#   processed 136000 CDR3s
#   processed 136100 CDR3s
#   processed 136200 CDR3s
#   processed 136300 CDR3s
#   processed 136400 CDR3s
#   processed 136500 CDR3s
#   processed 136600 CDR3s
#   processed 136700 CDR3s
#   processed 136800 CDR3s
#   processed 136900 CDR3s
#   processed 137000 CDR3s
#   processed 137100 CDR3s
#   processed 137200 CDR3s
#   processed 137300 CDR3s
#   processed 137400 CDR3s
#   processed 137500 CDR3s
#   processed 137600 CDR3s
#   processed 137700 CDR3s
#   processed 137800 CDR3s
#   processed 137900 CDR3s
#   processed 138000 CDR3s
#   processed 138100 CDR3s
#   processed 138200 CDR3s
#   processed 138300 CDR3s
#   processed 138400 CDR3s
#   processed 138500 CDR3s
#   processed 138600 CDR3s
#   processed 138700 CDR3s
#   processed 138800 CDR3s
#   processed 138900 CDR3s
#   processed 139000 CDR3s
#   processed 139100 CDR3s
#   processed 139200 CDR3s
#   processed 139300 CDR3s
#   processed 139400 CDR3s
#   processed 139500 CDR3s
#   processed 139600 CDR3s
#   processed 139700 CDR3s
#   processed 139800 CDR3s
#   processed 139900 CDR3s
#   processed 140000 CDR3s
#   processed 140100 CDR3s
#   processed 140200 CDR3s
#   processed 140300 CDR3s
#   processed 140400 CDR3s
#   processed 140500 CDR3s
#   processed 140600 CDR3s
#   processed 140700 CDR3s
#   processed 140800 CDR3s
#   processed 140900 CDR3s
#   processed 141000 CDR3s
#   processed 141100 CDR3s
#   processed 141200 CDR3s
#   processed 141300 CDR3s
#   processed 141400 CDR3s
#   processed 141500 CDR3s
#   processed 141600 CDR3s
#   processed 141700 CDR3s
#   processed 141800 CDR3s
#   processed 141900 CDR3s
#   processed 142000 CDR3s
#   processed 142100 CDR3s
#   processed 142200 CDR3s
#   processed 142300 CDR3s
#   processed 142400 CDR3s
#   processed 142500 CDR3s
#   processed 142600 CDR3s
#   processed 142700 CDR3s
#   processed 142800 CDR3s
#   processed 142900 CDR3s
#   processed 143000 CDR3s
#   processed 143100 CDR3s
#   processed 143200 CDR3s
#   processed 143300 CDR3s
#   processed 143400 CDR3s
#   processed 143500 CDR3s
#   processed 143600 CDR3s
#   processed 143700 CDR3s
#   processed 143800 CDR3s
#   processed 143900 CDR3s
#   processed 144000 CDR3s
#   processed 144100 CDR3s
#   processed 144200 CDR3s
#   processed 144300 CDR3s
#   processed 144400 CDR3s
#   processed 144500 CDR3s
#   processed 144600 CDR3s
#   processed 144700 CDR3s
#   processed 144800 CDR3s
#   processed 144900 CDR3s
#   processed 145000 CDR3s
#   processed 145100 CDR3s
#   processed 145200 CDR3s
#   processed 145300 CDR3s
#   processed 145400 CDR3s
#   processed 145500 CDR3s
#   processed 145600 CDR3s
#   processed 145700 CDR3s
#   processed 145800 CDR3s
#   processed 145900 CDR3s
#   processed 146000 CDR3s
#   processed 146100 CDR3s
#   processed 146200 CDR3s
#   processed 146300 CDR3s
#   processed 146400 CDR3s
#   processed 146500 CDR3s
#   processed 146600 CDR3s
#   processed 146700 CDR3s
#   processed 146800 CDR3s
#   processed 146900 CDR3s
#   processed 147000 CDR3s
#   processed 147100 CDR3s
#   processed 147200 CDR3s
#   processed 147300 CDR3s
#   processed 147400 CDR3s
#   processed 147500 CDR3s
# 1
# ✅ Wrote rows 0 to 10000
# ✅ Wrote rows 10000 to 20000
# ✅ Wrote rows 20000 to 30000
# ✅ Wrote rows 30000 to 40000
# ✅ Wrote rows 40000 to 50000
# ✅ Wrote rows 50000 to 60000
# ✅ Wrote rows 60000 to 70000
# ✅ Wrote rows 70000 to 80000
# ✅ Wrote rows 80000 to 90000
# ✅ Wrote rows 90000 to 100000
# ✅ Wrote rows 100000 to 110000
# ✅ Wrote rows 110000 to 120000
# ✅ Wrote rows 120000 to 130000
# ✅ Wrote rows 130000 to 140000
# ✅ Wrote rows 140000 to 150000
# 1

# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()
